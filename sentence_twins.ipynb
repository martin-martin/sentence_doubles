# %%
import nltk
from nltk.corpus import gutenberg as gb
from pprint import pprint

# %% [markdown]
# #

# %%
pprint(gb.fileids())
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
text = gb.raw(fileids='chesterton-thursday.txt')

# %%
# looking for a sentence I like
#print(text[500:1000])

# %%
sentence = "The world was very old indeed when you and I were young."

# %%
text.find(sentence)
# Out:
# 598

# %%
len(text)
# Out:
# 320525

# %%
text.find(sentence, 599)
# Out:
# -1

# %% [markdown]
# ## Okay, let's dive deeper (and broader)
#
# The first try was an exploratory random sample (selected by flavor). Let's put this whole thing onto different feet.

# %%
sent_tok = gb.sents(fileids="chesterton-thursday.txt")

# %%
print(sent_tok)
# Out:
# [['[', 'The', 'Man', 'Who', 'Was', 'Thursday', 'by', 'G', '.', 'K', '.', 'Chesterton', '1908', ']'], ['To', 'Edmund', 'Clerihew', 'Bentley'], ...]

# %%
len(sent_tok)
# Out:
# 3742

# %%
from random import randint

# %%
rand_sent_i = randint(0, len(sent_tok))

# %%
rand_sent = " ".join(sent_tok[rand_sent_i])

# %%
import re
pattern = re.compile(r'\s(?=[",\.])')

# %%
len(pattern.findall(rand_sent))
# Out:
# 6

# %%
rand_sent
# Out:
# '" Not so bad as that ," said Dr . Bull , with unnecessary laughter , " not so bad as that .'

# %% [markdown]
# So here we have a problem, because different things need to be treated in a different way. My randome example sentence:
# >'" Not so bad as that ," said Dr . Bull , with unnecessary laughter , " not so bad as that .'
#
# Has quotation marks " that need in some case have the whitespace removed before them, and sometimes after.
# I'm not gonna deal with that now. :)
#
# But I will complete the job of removing the other spaces, those before sentence delimiters such as , and .

# %%
re.sub(pattern, "", rand_sent)
# Out:
# '" Not so bad as that," said Dr. Bull, with unnecessary laughter," not so bad as that.'

# %% [markdown]
# This is pretty neat, but it misses some finesse:
# >'" Not so bad as that," said Dr. Bull, with unnecessary laughter," not so bad as that.'
#
# That I am not gonna provide right now.
# I take it.

# %% [markdown]
# ## Clean up and formalize

# %%
def get_rand_sentence(sent_tok_corpus):
    import re
    from random import randint
    
    num_of_sents = len(sent_tok_corpus)
    rand_sent_i = randint(0, len(sent_tok_corpus))
    rand_sent = " ".join(sent_tok_corpus[rand_sent_i])
    pattern = re.compile(r'\s(?=[^\w])')
    rand_sent = re.sub(pattern, "", rand_sent)
    return rand_sent

# %%
# good enough
print(get_rand_sentence(sent_tok))
# Out:
# Syme' s family, like most of those who end in the simple life, had once owned a motor, and he knew all about them.

# %%
def find_sentence_twins(corpus, sentence):
    import re
    pattern = re.compile(sentence)
    matches = re.findall(pattern, corpus)
    return matches

# %%
text = gb.raw(fileids='chesterton-thursday.txt')
print(rand_sent)
# Out:
# " Not so bad as that ," said Dr . Bull , with unnecessary laughter , " not so bad as that .

# %%
print(find_sentence_twins(text, rand_sent))
# Out:
# []

# %%
corpora = gb.fileids()

# %%
def scan_corpora(list_of_corpora):
    all_matches = {}
    for c in list_of_corpora:
        raw_corpus = gb.raw(fileids=c)
        sent_tok_corpus = gb.sents(fileids=c)
        rand_sent = get_rand_sentence(sent_tok_corpus)
        corpus_matched = find_sentence_twins(raw_corpus, rand_sent)
        all_matches[c] = corpus_matched
    return all_matches

# %%
twins = scan_corpora(corpora)

# %%
pprint(twins)
# Out:
# {'austen-emma.txt': [],
#  'austen-persuasion.txt': [],
#  'austen-sense.txt': [],
#  'bible-kjv.txt': [],
#  'blake-poems.txt': [],
#  'bryant-stories.txt': [],
#  'burgess-busterbrown.txt': [],
#  'carroll-alice.txt': [],
#  'chesterton-ball.txt': ['shouted Turnbull ',
#                          'shouted Turnbull.',
#                          'shouted Turnbull ',
#                          'shouted Turnbull.'],
#  'chesterton-brown.txt': [],
#  'chesterton-thursday.txt': [],
#  'edgeworth-parents.txt': ['Now you are sure of the main with Lord John.'],
#  'melville-moby_dick.txt': [],
#  'milton-paradise.txt': [],
#  'shakespeare-caesar.txt': [],
#  'shakespeare-hamlet.txt': ['Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hors',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hors',
#                             'Hors',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hors',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hors',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hora',
#                             'Hora',
#                             'Hora',
#                             'Hor.',
#                             'Hor.',
#                             'Hor.'],
#  'shakespeare-macbeth.txt': ['The Witches Dance, and vanish.'],
#  'whitman-leaves.txt': []}

# %% [markdown]
# Now here are some issues. Due to the fact that my regex doesn't create completely sound sentences, many return no matches at all (while there should be at least one.
#
# hm, this could work if I simply treat them all the same, and piece the whole corpus together shadily too.

# %%
def get_rand_sentence(sent_tok_corpus):
    import re
    from random import randint
    
    num_of_sents = len(sent_tok_corpus)
    rand_sent_i = randint(0, len(sent_tok_corpus))
    rand_sent = " ".join(sent_tok_corpus[rand_sent_i])
    return rand_sent

def scan_corpora(list_of_corpora):
    all_matches = {}
    for c in list_of_corpora:
        sent_tok_corpus = gb.sents(fileids=c)
        full_corpus = ""
        for sent in sent_tok_corpus:
            sentence = " ".join(sent)
            full_corpus += sentence
        rand_sent = get_rand_sentence(sent_tok_corpus)
        corpus_matched = find_sentence_twins(full_corpus, rand_sent)
        all_matches[c] = (rand_sent, corpus_matched)
    return all_matches

# %%
twins = scan_corpora(corpora)

# %%
pprint(twins)
# Out:
# {'austen-emma.txt': ('" Well , Emma , I do not believe I have any thing more '
#                      "to say about the boys ; but you have your sister ' s "
#                      'letter , and every thing is down at full length there we '
#                      'may be sure .',
#                      ['" Well , Emma , I do not believe I have any thing more '
#                       "to say about the boys ; but you have your sister ' s "
#                       'letter , and every thing is down at full length there '
#                       'we may be sure .']),
#  'austen-persuasion.txt': ('She only consulted Lady Russell , who entered '
#                            'thoroughly into her sentiments , and was most '
#                            "happy to convey her as near to Mrs Smith ' s "
#                            'lodgings in Westgate Buildings , as Anne chose to '
#                            'be taken .',
#                            ['She only consulted Lady Russell , who entered '
#                             'thoroughly into her sentiments , and was most '
#                             "happy to convey her as near to Mrs Smith ' s "
#                             'lodgings in Westgate Buildings , as Anne chose to '
#                             'be taken .']),
#  'austen-sense.txt': ('My Elinor , you do not yet know all my happiness .',
#                       ['My Elinor , you do not yet know all my happiness .']),
#  'bible-kjv.txt': ('3 : 11 But Jehoshaphat said , Is there not here a prophet '
#                    'of the LORD , that we may enquire of the LORD by him ?',
#                    ['3 : 11 But Jehoshaphat said , Is there not here a prophet '
#                     'of the LORD , that we may enquire of the LORD by him ']),
#  'blake-poems.txt': ("Struggling in my father ' s hands , Striving against my "
#                      'swaddling - bands , Bound and weary , I thought best To '
#                      "sulk upon my mother ' s breast .",
#                      ["Struggling in my father ' s hands , Striving against my "
#                       'swaddling - bands , Bound and weary , I thought best To '
#                       "sulk upon my mother ' s breast ."]),
#  'bryant-stories.txt': ('( A banyan tree is a kind of fruit tree .)',
#                         [' A banyan tree is a kind of fruit tree .']),
#  'burgess-busterbrown.txt': ('I can eat all I want and get back to the Green '
#                              'Forest before there is any danger that Farmer '
#                              "Brown ' s boy or any one else I ' m afraid of "
#                              'will see me .',
#                              ['I can eat all I want and get back to the Green '
#                               'Forest before there is any danger that Farmer '
#                               "Brown ' s boy or any one else I ' m afraid of "
#                               'will see me .']),
#  'carroll-alice.txt': ("' That ' s right !'", ["' That ' s right !'"]),
#  'chesterton-ball.txt': ('Its bewildering squares and parallelograms were '
#                          'compact and perfect as a Chinese puzzle ; an '
#                          'enormous hieroglyphic which man must decipher or die '
#                          '.',
#                          ['Its bewildering squares and parallelograms were '
#                           'compact and perfect as a Chinese puzzle ; an '
#                           'enormous hieroglyphic which man must decipher or '
#                           'die .']),
#  'chesterton-brown.txt': ('If the convict was not keeping the shot for Todd , '
#                           "as he evidently wasn ' t , it is most likely that "
#                           'he was keeping it for Lord Falconroy ; and it looks '
#                           'as if he had delivered the goods .',
#                           ['If the convict was not keeping the shot for Todd , '
#                            "as he evidently wasn ' t , it is most likely that "
#                            'he was keeping it for Lord Falconroy ; and it '
#                            'looks as if he had delivered the goods .']),
#  'chesterton-thursday.txt': ('I know that he will not hear it tonight , though '
#                              'my passion were to rend the roof .',
#                              ['I know that he will not hear it tonight , '
#                               'though my passion were to rend the roof .']),
#  'edgeworth-parents.txt': ('The two friends took leave of one another very '
#                            'sorrowfully .',
#                            ['The two friends took leave of one another very '
#                             'sorrowfully .']),
#  'melville-moby_dick.txt': ('150 , 000 lbs .', ['150 , 000 lbs .']),
#  'milton-paradise.txt': ('O , then , at last relent : Is there no place Left '
#                          'for repentance , none for pardon left ?',
#                          ['O , then , at last relent : Is there no place Left '
#                           'for repentance , none for pardon left ']),
#  'shakespeare-caesar.txt': ('Fill Lucius , till the Wine ore - swell the Cup : '
#                             'I cannot drinke too much of Brutus loue .',
#                             ['Fill Lucius , till the Wine ore - swell the Cup '
#                              ': I cannot drinke too much of Brutus loue .']),
#  'shakespeare-hamlet.txt': ('Do not forget : this Visitation Is but to whet '
#                             'thy almost blunted purpose .',
#                             ['Do not forget : this Visitation Is but to whet '
#                              'thy almost blunted purpose .']),
#  'shakespeare-macbeth.txt': ('I',
#                              ['I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I',
#                               'I']),
#  'whitman-leaves.txt': ('My sun has his sun and round him obediently wheels , '
#                         'He joins with his partners a group of superior '
#                         'circuit , And greater sets follow , making specks of '
#                         'the greatest inside them .',
#                         ['My sun has his sun and round him obediently wheels , '
#                          'He joins with his partners a group of superior '
#                          'circuit , And greater sets follow , making specks of '
#                          'the greatest inside them .'])}

# %%
macbeth = gb.sents(fileids="shakespeare-macbeth.txt")

# %%
macbeth
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]

# %%
macbeth[20:40]
# Out:
# [['All', '.'],
#  ['Padock',
#   'calls',
#   'anon',
#   ':',
#   'faire',
#   'is',
#   'foule',
#   ',',
#   'and',
#   'foule',
#   'is',
#   'faire',
#   ',',
#   'Houer',
#   'through',
#   'the',
#   'fogge',
#   'and',
#   'filthie',
#   'ayre',
#   '.'],
#  ['Exeunt', '.'],
#  ['Scena', 'Secunda', '.'],
#  ['Alarum', 'within', '.'],
#  ['Enter',
#   'King',
#   'Malcome',
#   ',',
#   'Donalbaine',
#   ',',
#   'Lenox',
#   ',',
#   'with',
#   'attendants',
#   ',',
#   'meeting',
#   'a',
#   'bleeding',
#   'Captaine',
#   '.'],
#  ['King', '.'],
#  ['What', 'bloody', 'man', 'is', 'that', '?'],
#  ['he',
#   'can',
#   'report',
#   ',',
#   'As',
#   'seemeth',
#   'by',
#   'his',
#   'plight',
#   ',',
#   'of',
#   'the',
#   'Reuolt',
#   'The',
#   'newest',
#   'state'],
#  ['Mal', '.'],
#  ['This',
#   'is',
#   'the',
#   'Serieant',
#   ',',
#   'Who',
#   'like',
#   'a',
#   'good',
#   'and',
#   'hardie',
#   'Souldier',
#   'fought',
#   "'",
#   'Gainst',
#   'my',
#   'Captiuitie',
#   ':',
#   'Haile',
#   'braue',
#   'friend',
#   ';',
#   'Say',
#   'to',
#   'the',
#   'King',
#   ',',
#   'the',
#   'knowledge',
#   'of',
#   'the',
#   'Broyle',
#   ',',
#   'As',
#   'thou',
#   'didst',
#   'leaue',
#   'it'],
#  ['Cap', '.'],
#  ['Doubtfull',
#   'it',
#   'stood',
#   ',',
#   'As',
#   'two',
#   'spent',
#   'Swimmers',
#   ',',
#   'that',
#   'doe',
#   'cling',
#   'together',
#   ',',
#   'And',
#   'choake',
#   'their',
#   'Art',
#   ':',
#   'The',
#   'mercilesse',
#   'Macdonwald',
#   '(',
#   'Worthie',
#   'to',
#   'be',
#   'a',
#   'Rebell',
#   ',',
#   'for',
#   'to',
#   'that',
#   'The',
#   'multiplying',
#   'Villanies',
#   'of',
#   'Nature',
#   'Doe',
#   'swarme',
#   'vpon',
#   'him',
#   ')',
#   'from',
#   'the',
#   'Westerne',
#   'Isles',
#   'Of',
#   'Kernes',
#   'and',
#   'Gallowgrosses',
#   'is',
#   'supply',
#   "'",
#   'd',
#   ',',
#   'And',
#   'Fortune',
#   'on',
#   'his',
#   'damned',
#   'Quarry',
#   'smiling',
#   ',',
#   'Shew',
#   "'",
#   'd',
#   'like',
#   'a',
#   'Rebells',
#   'Whore',
#   ':',
#   'but',
#   'all',
#   "'",
#   's',
#   'too',
#   'weake',
#   ':',
#   'For',
#   'braue',
#   'Macbeth',
#   '(',
#   'well',
#   'hee',
#   'deserues',
#   'that',
#   'Name',
#   ')',
#   'Disdayning',
#   'Fortune',
#   ',',
#   'with',
#   'his',
#   'brandisht',
#   'Steele',
#   ',',
#   'Which',
#   'smoak',
#   "'",
#   'd',
#   'with',
#   'bloody',
#   'execution',
#   '(',
#   'Like',
#   'Valours',
#   'Minion',
#   ')',
#   'caru',
#   "'",
#   'd',
#   'out',
#   'his',
#   'passage',
#   ',',
#   'Till',
#   'hee',
#   'fac',
#   "'",
#   'd',
#   'the',
#   'Slaue',
#   ':',
#   'Which',
#   'neu',
#   "'",
#   'r',
#   'shooke',
#   'hands',
#   ',',
#   'nor',
#   'bad',
#   'farwell',
#   'to',
#   'him',
#   ',',
#   'Till',
#   'he',
#   'vnseam',
#   "'",
#   'd',
#   'him',
#   'from',
#   'the',
#   'Naue',
#   'toth',
#   "'",
#   'Chops',
#   ',',
#   'And',
#   'fix',
#   "'",
#   'd',
#   'his',
#   'Head',
#   'vpon',
#   'our',
#   'Battlements'],
#  ['King', '.'],
#  ['O', 'valiant', 'Cousin', ',', 'worthy', 'Gentleman'],
#  ['Cap', '.'],
#  ['As',
#   'whence',
#   'the',
#   'Sunne',
#   "'",
#   'gins',
#   'his',
#   'reflection',
#   ',',
#   'Shipwracking',
#   'Stormes',
#   ',',
#   'and',
#   'direfull',
#   'Thunders',
#   ':',
#   'So',
#   'from',
#   'that',
#   'Spring',
#   ',',
#   'whence',
#   'comfort',
#   'seem',
#   "'",
#   'd',
#   'to',
#   'come',
#   ',',
#   'Discomfort',
#   'swells',
#   ':',
#   'Marke',
#   'King',
#   'of',
#   'Scotland',
#   ',',
#   'marke',
#   ',',
#   'No',
#   'sooner',
#   'Iustice',
#   'had',
#   ',',
#   'with',
#   'Valour',
#   'arm',
#   "'",
#   'd',
#   ',',
#   'Compell',
#   "'",
#   'd',
#   'these',
#   'skipping',
#   'Kernes',
#   'to',
#   'trust',
#   'their',
#   'heeles',
#   ',',
#   'But',
#   'the',
#   'Norweyan',
#   'Lord',
#   ',',
#   'surueying',
#   'vantage',
#   ',',
#   'With',
#   'furbusht',
#   'Armes',
#   ',',
#   'and',
#   'new',
#   'supplyes',
#   'of',
#   'men',
#   ',',
#   'Began',
#   'a',
#   'fresh',
#   'assault'],
#  ['King', '.'],
#  ['Dismay',
#   "'",
#   'd',
#   'not',
#   'this',
#   'our',
#   'Captaines',
#   ',',
#   'Macbeth',
#   'and',
#   'Banquoh',
#   '?'],
#  ['Cap', '.']]

# %% [markdown]
# Okay, this can get corrected. I'll only take "sentences" that have a lenght of > 5 units (words + delimiters, since sent_tokenizer treats them as units of meaning).

# %%
def get_rand_sentence(sent_tok_corpus):
    import re
    from random import randint
    
    num_of_sents = len(sent_tok_corpus)
    # introduce a check to avoid senseless macbeth outcries
    rand_sent = ""
    while len(rand_sent) < 5:
        rand_sent_i = randint(0, len(sent_tok_corpus))
        rand_sent = " ".join(sent_tok_corpus[rand_sent_i])
    return rand_sent

# %%
twins = scan_corpora(corpora)

# %%
pprint(twins)
# Out:
# {'austen-emma.txt': ('This was astonishing !-- She could not have believed it '
#                      'possible that the taste or the pride of Miss Fairfax '
#                      'could endure such society and friendship as the Vicarage '
#                      'had to offer .',
#                      ['This was astonishing !-- She could not have believed it '
#                       'possible that the taste or the pride of Miss Fairfax '
#                       'could endure such society and friendship as the '
#                       'Vicarage had to offer .']),
#  'austen-persuasion.txt': ('He looked at her with a smile , and a little '
#                            'motion of the head , which expressed , " Come to '
#                            'me , I have something to say ;" and the unaffected '
#                            ', easy kindness of manner which denoted the '
#                            'feelings of an older acquaintance than he really '
#                            'was , strongly enforced the invitation .',
#                            ['He looked at her with a smile , and a little '
#                             'motion of the head , which expressed , " Come to '
#                             'me , I have something to say ;" and the '
#                             'unaffected , easy kindness of manner which '
#                             'denoted the feelings of an older acquaintance '
#                             'than he really was , strongly enforced the '
#                             'invitation .']),
#  'austen-sense.txt': ('my dear child , do you accuse Willoughby and Marianne '
#                       'of concealment ?',
#                       ['my dear child , do you accuse Willoughby and Marianne '
#                        'of concealment ']),
#  'bible-kjv.txt': ('3 : 3 And they set the altar upon his bases ; for fear was '
#                    'upon them because of the people of those countries : and '
#                    'they offered burnt offerings thereon unto the LORD , even '
#                    'burnt offerings morning and evening .',
#                    ['3 : 3 And they set the altar upon his bases ; for fear '
#                     'was upon them because of the people of those countries : '
#                     'and they offered burnt offerings thereon unto the LORD , '
#                     'even burnt offerings morning and evening .']),
#  'blake-poems.txt': ('Dear mother , dear mother , the Church is cold ; But the '
#                      'Alehouse is healthy , and pleasant , and warm .',
#                      ['Dear mother , dear mother , the Church is cold ; But '
#                       'the Alehouse is healthy , and pleasant , and warm .']),
#  'bryant-stories.txt': ('" No longer will Frode sit on his throne , and rule '
#                         'over rings of red gold and mighty millstones .',
#                         ['" No longer will Frode sit on his throne , and rule '
#                          'over rings of red gold and mighty millstones .']),
#  'burgess-busterbrown.txt': ('" You ought to know by this time that no good '
#                              'comes of stealing ."',
#                              ['" You ought to know by this time that no good '
#                               'comes of stealing ."']),
#  'carroll-alice.txt': ('Lastly , she pictured to herself how this same little '
#                        'sister of hers would , in the after - time , be '
#                        'herself a grown woman ; and how she would keep , '
#                        'through all her riper years , the simple and loving '
#                        'heart of her childhood : and how she would gather '
#                        'about her other little children , and make THEIR eyes '
#                        'bright and eager with many a strange tale , perhaps '
#                        'even with the dream of Wonderland of long ago : and '
#                        'how she would feel with all their simple sorrows , and '
#                        'find a pleasure in all their simple joys , remembering '
#                        'her own child - life , and the happy summer days .',
#                        ['Lastly , she pictured to herself how this same little '
#                         'sister of hers would , in the after - time , be '
#                         'herself a grown woman ; and how she would keep , '
#                         'through all her riper years , the simple and loving '
#                         'heart of her childhood : and how she would gather '
#                         'about her other little children , and make THEIR eyes '
#                         'bright and eager with many a strange tale , perhaps '
#                         'even with the dream of Wonderland of long ago : and '
#                         'how she would feel with all their simple sorrows , '
#                         'and find a pleasure in all their simple joys , '
#                         'remembering her own child - life , and the happy '
#                         'summer days .']),
#  'chesterton-ball.txt': ('A few yards from them along the road a lean and '
#                          'starved sort of hedge came pitifully to an end .',
#                          ['A few yards from them along the road a lean and '
#                           'starved sort of hedge came pitifully to an end .']),
#  'chesterton-brown.txt': ('In the grey distance the big bandstand of a '
#                           'watering - place stood up like a giant mushroom '
#                           'with six legs .',
#                           ['In the grey distance the big bandstand of a '
#                            'watering - place stood up like a giant mushroom '
#                            'with six legs .']),
#  'chesterton-thursday.txt': ('In the wild events which were to follow this '
#                              'girl had no part at all ; he never saw her again '
#                              'until all his tale was over .',
#                              ['In the wild events which were to follow this '
#                               'girl had no part at all ; he never saw her '
#                               'again until all his tale was over .']),
#  'edgeworth-parents.txt': ("I ' m sure it ' s what I can ' t pretend to , "
#                            'unless you do me the justice to forbid him my '
#                            'places ."',
#                            ["I ' m sure it ' s what I can ' t pretend to , "
#                             'unless you do me the justice to forbid him my '
#                             'places ."']),
#  'melville-moby_dick.txt': ('So omnipotent is art ; which in many a district '
#                             'of New Bedford has superinduced bright terraces '
#                             'of flowers upon the barren refuse rocks thrown '
#                             "aside at creation ' s final day .",
#                             ['So omnipotent is art ; which in many a district '
#                              'of New Bedford has superinduced bright terraces '
#                              'of flowers upon the barren refuse rocks thrown '
#                              "aside at creation ' s final day ."]),
#  'milton-paradise.txt': ('He , bolder now , uncalled before her stood , But as '
#                          'in gaze admiring : oft he bowed His turret crest , '
#                          'and sleek enamelled neck , Fawning ; and licked the '
#                          'ground whereon she trod .',
#                          ['He , bolder now , uncalled before her stood , But '
#                           'as in gaze admiring : oft he bowed His turret crest '
#                           ', and sleek enamelled neck , Fawning ; and licked '
#                           'the ground whereon she trod .']),
#  'shakespeare-caesar.txt': ('Who will go with me ?', ['Who will go with me ']),
#  'shakespeare-hamlet.txt': ('Oh what a Rogue and Pesant slaue am I ?',
#                             ['Oh what a Rogue and Pesant slaue am I ']),
#  'shakespeare-macbeth.txt': ("Giue me my Sword : who ' s there ?",
#                              ["Giue me my Sword : who ' s there "]),
#  'whitman-leaves.txt': ('for I think I have reason to be the proudest son '
#                         'alive -- for I am the son of the brawny and tall - '
#                         'topt city , And who has been bold and true ?',
#                         ['for I think I have reason to be the proudest son '
#                          'alive -- for I am the son of the brawny and tall - '
#                          'topt city , And who has been bold and true '])}

# %% [markdown]
# BAM. That's it. I've got my code. :)
