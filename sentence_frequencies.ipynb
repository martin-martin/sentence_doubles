# %%
import nltk

# %%
# creating a corpus of real text
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text5.concordance("U73")
# Out:
# Displaying 11 of 11 matches:
# d yoko say when John got shot lmao hi U73 ono My bad U70 .. you not the same on
# ou not the same one oh shit hey there U73 what tv show did the beattles sing om
# t tv show did the beattles sing om hi U73 heya U7 ! h shit i get all ur money n
#  U74 ed sullivan show ((((((((((((((( U73 )))))))))))))) right U55 hi U68 ! hi
# ts yeah U72 it is nice 1 U72 JOIN hey U73 heya U24 ltns PART yeah ... life , yo
#  the wheel of a peddle car PART later U73 , off to burger king to find me some
# i * poof * PART PART PART JOIN thanks U73 sure hey U49 any sexy females want to
#  37 m wv brb PART PART why you moving U73 .... its smells like roses . ACTION t
# help then did it ? i am thinking so , U73 lol U27 !!!! guess not ... lol I love
# .. so full of helpful advice .... lol U73 : How much do you think it is ? I 'll
# hahahaha !!!!!! anyone in texas night U73 lmao he told you not to call me yeste

# %%
text5.similar("lmao")
# Out:
# part hi join lol hey no yeah and wb how everyone ok well like haha
# evening hahaha yep now me

# %%
text2.similar("nice")
# Out:
# spent now interesting seated few settled only busy loud come lucky
# answered pleasing employed wrong censure careful lost already governed

# %%
text3.similar("terror")
# Out:
# midst city smoke waters dukes power fowl dread purchase inhabitants
# cities brother knowledge isles labour people sight names sister
# garments

# %%
text4.similar("terror")
# Out:
# freedom life liberty knowledge power congress peace history government
# duty nations wealth suffering war executive civilization sacrifice
# service time courts

# %%
text4.dispersion_plot(["flight", "plane", "time", "relax"])

# %%
text5.dispersion_plot(["lol", "lmao", "haha", "hahaha"])

# %%
text1.common_contexts(["blows", "whale"])
# Out:
# the_of

# %%
all_texts = [text1, text2, text3, text4, text5, text6, text7, text8, text9]

# %%
for text in all_texts:
    print(text)
    text.dispersion_plot(["catch", "flight", "tomorrow", "stay", "another", "day"])
# Out:
# <Text: Moby Dick by Herman Melville 1851>
# <Text: Sense and Sensibility by Jane Austen 1811>
# <Text: The Book of Genesis>
# <Text: Inaugural Address Corpus>
# <Text: Chat Corpus>
# <Text: Monty Python and the Holy Grail>
# <Text: Wall Street Journal>
# <Text: Personals Corpus>
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>
